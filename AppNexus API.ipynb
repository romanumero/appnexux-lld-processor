# %%
from nexusadspy import AppnexusClient

# %%
client = AppnexusClient(username='damon@centrois.com', password='Rbzq4ktr!', path='.appnexus_auth.json')

# %%
client.request('operating-system-extended','GET')
# Out:
# [{'id': 0,
#   'name': 'Unknown',
#   'search_string': None,
#   'last_modified': '2016-03-24 17:21:05',
#   'family': {'id': '1', 'name': 'Unknown'}},
#  {'id': 15,
#   'name': 'Android 2.2 Froyo',
#   'search_string': 'Android 2.2',
#   'last_modified': '2013-07-23 21:55:22',
#   'family': {'id': '2', 'name': 'Android'}},
#  {'id': 16,
#   'name': 'Android 2.2.1 Froyo',
#   'search_string': 'Android 2.2.1',
#   'last_modified': '2013-07-23 21:55:22',
#   'family': {'id': '2', 'name': 'Android'}},
#  {'id': 17,
#   'name': 'Android 2.2.2 Froyo',
#   'search_string': 'Android 2.2.2',
#   'last_modified': '2013-07-23 21:55:22',
#   'family': {'id': '2', 'name': 'Android'}},
#  {'id': 18,
#   'name': 'Android 2.2.3 Froyo',
#   'search_string': 'Android 2.2.3',
#   'last_modified': '2013-07-23 21:55:22',
#   'family': {'id': '2', 'name': 'Android'}},
#  {'id': 19,
#   'name': 'Android 2.3 Gingerbread',
#   'search_string': 'Android 2.3',
#   'last_modified': '2013-07-23 21:55:22',
# ...
